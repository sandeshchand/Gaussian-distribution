# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeshchand/Gaussian-distribution/blob/main/Distribution(July4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## We will check whether distribution is Guassian distributed or not
## QQ(Quantile Quantile) plot

import numpy as np
import statsmodels.api as sm
import pylab as py
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# np.random generates different random numbers
# whenever the code is executed
# Note: When you execute the same code
# the graph look different than shown below.

# Random data points generated for standard normal distribution
data_points = np.random.normal(0, 1, 100)	
print(data_points)

sm.qqplot(data_points, line ='45')
py.show()
# Out:
# [-8.32767161e-01 -8.67616695e-01  3.76423139e-01 -1.08786020e+00
#  -7.28512055e-01  4.77409759e-01  5.69023815e-01  1.74759924e+00
#   3.62745197e-01  9.39777833e-01 -1.05856507e-01  2.14869296e-01
#  -1.34183275e+00 -1.38139118e+00 -2.78866212e-01 -1.25262344e+00
#  -2.07860069e-01 -6.92630160e-01 -2.07440816e-01 -1.53441514e-01
#   1.96012999e-01  2.33186999e+00 -8.63401179e-02  8.45091814e-01
#   5.36363391e-01  2.59777960e-02 -8.50329402e-01  6.14870344e-01
#  -3.82141290e-01 -1.73774655e+00 -4.03576257e-01 -6.09030044e-01
#   1.01840714e+00  1.28184373e+00 -6.81691060e-01 -7.37357966e-01
#  -3.89096748e-01  1.72977107e+00 -6.42350212e-01  7.85991243e-02
#  -3.55464322e-01  2.01401557e+00  8.55491314e-01  1.24826199e+00
#  -8.11367844e-02  1.55511145e-01  5.46281250e-01  4.14839908e-01
#   4.88741860e-01 -5.70119185e-01  2.18695324e-01  1.62968036e-01
#  -1.17890407e+00  2.74524506e-01 -2.06121763e-01 -1.29669214e-01
# ...

# %%
data_points = np.random.normal(0, 1, 100)	
data_points
# Out:
# array([ 0.79141182,  0.96267982,  1.03334287,  0.91640777, -0.87656212,
#         0.75255558,  1.32186636,  0.55481681, -1.23016587, -1.40810158,
#         0.54989743, -0.58408835, -0.07990753,  1.68046308, -0.05093596,
#        -1.77786707, -0.57775228,  1.88561757, -0.03509806, -0.31504957,
#        -1.26110319, -0.02164076,  1.09101885, -0.07161738,  1.18838782,
#         0.28291927,  0.79185332,  0.23706502, -1.81324486,  2.07188726,
#        -0.09099782,  0.03055234, -0.59437726, -1.42940281,  0.14983276,
#         1.05966854, -0.7119554 ,  0.51425017,  2.13029633,  1.22465265,
#         0.84482989, -1.26456613,  1.15144719, -0.34598398, -0.02564129,
#        -0.02257125, -1.20678681, -0.97783569,  0.35287945,  0.89792546,
#         0.80403968,  1.53106591, -0.55811081,  0.71310684, -0.47419316,
#        -0.48303325, -1.58186381,  0.84029391, -0.12691479,  0.03780489,
#        -0.36600436, -1.58894608, -0.47909549,  1.19139648, -0.19856375,
# ...

# %%
import seaborn as sns
sns.displot(data_points,kind='kde')

# %%
data = np.random.lognormal(0, 1, 100)	
data
import seaborn as sns
sns.displot(data,kind="kde")
sm.qqplot(data, line ='45')
py.show()

# %%
log_data=np.log(data)
sm.qqplot(log_data, line ='45' )
py.show( )

# %%
sm.qqplot(  )
